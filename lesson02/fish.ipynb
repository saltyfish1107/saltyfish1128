# %%
import csv
with open ('64家醫院-分級-地址電話1131004.csv',encoding='utf-8') as file:
    csvReader=csv.reader(file)
    print(type(csvReader))
    for row in csvReader:
            print(row)
# Out:
# <class '_csv.reader'>
# ['\ufeff序號', '醫院分級', '醫院名稱', '地址', '電話']
# ['1', '醫學中心', '中國醫藥大學附設醫院', '404327北區育德路2號', '(04)22052121']
# ['2', '醫學中心', '臺中榮民總醫院', '407220西屯區臺灣大道4段1650號', '(04)23592525']
# ['3', '醫學中心', '中山醫學大學附設醫院', '402306南區建國北路1段110號', '(04)24739595']
# ['4', '醫學中心', '中國醫藥大學兒童醫院', '404327北區育德路2號', '(04)22052121']
# ['5', '區域醫院', '澄清綜合醫院', '400620中區平等街139號', '(04)24632000']
# ['6', '區域醫院', '澄清綜合醫院中港分院', '407211西屯區臺灣大道4段966號', '(04)24632000']
# ['7', '區域醫院', '衛生福利部臺中醫院', '403301西區廣民里三民路1段199號', '(04)22294411']
# ['8', '區域醫院', '林新醫療社團法人林新醫院', '408346南屯區惠中路3段36號', '(04)22586688']
# ['9', '區域醫院', '衛生福利部豐原醫院', '420210豐原區安康路100號', '(04)25271180']
# ['10', '區域醫院', '國軍臺中總醫院附設民眾診療服務處', '411228太平區中山路二段348號', '(04)23934191']
# ['11', '區域醫院', '仁愛醫療財團法人大里仁愛醫院', '412224大里區東榮路483號', '(04)24819900']
# ['12', '區域醫院', '李綜合醫療社團法人大甲李綜合醫院', '437007大甲區八德街2號', '(04)26862288']
# ['13', '區域醫院', '光田醫療社團法人光田綜合醫院', '433401沙鹿區沙田路117號', '(04)26625111']
# ...
